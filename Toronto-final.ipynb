# %% [markdown]
# #### Using pandas to import the webpage

# %%
import pandas as pd
url = 'http://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
dfs = pd.read_html(url)

# %% [markdown]
# #### Check how many tables were imported

# %%
len(dfs)
# Out:
# 3

# %% [markdown]
# #### Check what is in the first table

# %%
dfs[0].head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Great this first table is what's needed!
# #### Next assign the first table to a new df

# %%
df=dfs[0]
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### Remove rows with Boroughs that are marked as "Not Assigned"

# %%
df = df.set_index("Borough")
df = df.drop('Not assigned', axis=0)
df = df.reset_index()
df.head()
# Out:
#             Borough Postcode     Neighbourhood
# 0        North York      M3A         Parkwoods
# 1        North York      M4A  Victoria Village
# 2  Downtown Toronto      M5A      Harbourfront
# 3  Downtown Toronto      M5A       Regent Park
# 4        North York      M6A  Lawrence Heights

# %% [markdown]
# #### Reformat the df to the required order in terms of column positioning

# %%
df = df.set_index("Postcode")
df = df.reset_index()
df.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights
# 5      M6A        North York    Lawrence Manor
# 6      M7A      Queen's Park      Not assigned
# 7      M9A         Etobicoke  Islington Avenue
# 8      M1B       Scarborough             Rouge
# 9      M1B       Scarborough           Malvern

# %% [markdown]
# #### Check the number of rows in the df for use in the next step

# %%
df.shape
# Out:
# (211, 3)

# %% [markdown]
# #### Use While loop and if statements to:
# ##### 1. Assign Borough to Neighbourhood where Neighbourhood as marked as "Not Assigned"
# ##### 2. Combine the Neighbourhood for the same Postcode and drop additional rows with same Postcode

# %%
r=0
trow = 210
while r < trow:
    if df.iloc[r,2] == 'Not assigned':
        df.iloc[r,2] = df.iloc[r,1]
    if df.iloc[r,0] == df.iloc [r+1,0]:
        df.iloc[r,2] = df.iloc[r,2] + ", " + df.iloc[r+1,2]
        df = df.drop([r+1], axis=0)
        df = df.reset_index(drop=True)
        trow = trow - 1
        r = r - 1
    r = r + 1
df.head(10)
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park
# 3      M6A        North York  Lawrence Heights, Lawrence Manor
# 4      M7A      Queen's Park                      Queen's Park
# 5      M9A         Etobicoke                  Islington Avenue
# 6      M1B       Scarborough                    Rouge, Malvern
# 7      M3B        North York                   Don Mills North
# 8      M4B         East York   Woodbine Gardens, Parkview Hill
# 9      M5B  Downtown Toronto          Ryerson, Garden District

# %% [markdown]
# ## Answer to Part 1, print the shape of the processed df

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Part 2 of the Assignment
# #### Combining the latitude and longtitude data

# %%
# !wget -O 'Geospatial_data.csv' http://cocl.us/Geospatial_data
# Out:
# --2019-06-15 09:03:05--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2019-06-15 09:03:05--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-06-15 09:03:09--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-06-15 09:03:09--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-06-15 09:03:09--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1
AWt88PhDZI3op1kyRifZZiD45rMIyQE9g18QXlucTKjVyO-lNFQOSKX2QLAkjL6mxttpNg9ycD7vY1E1euKHCbTEN5_fvgDksd7QW8fKKUTuqdAfhFs-KbEuAzEZhBHW9K6AexSyKbXZuCIOiB9N0TNNwIzU2vcl_q7MSnxAPypjE5NMQAp3uR22PifhQ2IhbfBa7V1YsTBi3_C_5byD4DrdFKkiAH_WZf9T0wWATRpsLgAXJJIw5VvtJCxiAF8WIndh-fgsiF4M5B8tW8LJAIWRI73088B9sEIttDwJ4WK2DqE2xPH_TvdBdj8WSYUEMFJSZ3-7bYm4asYUWSgbwVaKjLu98EK_VuVVUVzC6i7iPpq43wO4NUUa8e69dzwLUA_A5soZgC6LP_Sf_Qr4gCkiC_ChJE0zjVGf2VFlBHO1gw8s9t3CgqWuRkueoIS8OhbsmOTC_86e55nCaT758M4qWKBTYisWPvvorXy3mNRD7lP9JDyjH3wnjXdtYmfutFLmfG2RPrVi4l-ZWcC_v-ebfsuK5M9nL6u7Xu4AWwb-hkrEV6kwThMt4Z0uwQmRwvABNYXs5Dfa-5TjJFaSPWjtDp6CEuhVgO59wLHysMtgQaSKOhZQF68ZhLEt2VCh4GJHrABGkZJwlra8UvmIUOj-LGfxAqvPjqrI-YeL86KVh2KVXDvh-j8i8vaaNYww8HJT3ipomCAQnYIRwZSo-3g8BAYw2IDmDbww0H3M9uG3N1CN4rHxEroF-nyO0i_5PjC_RxgGEZn8imN75AlW1SHaNVXZTF2IQxUKZxt4Mg79t-0dO-AHjiqLCkYqaOJcYf2fL_KvHa57bTDLmjtVcGDVDJ_ioeSj4hfaXDBwYDVZ9nPNjuOTm2aNV-AOrt1xXWZIwNnmUBJbCa6fCM1koKVZFTg9hHQhNeajcADCAhFr1jZE8RUmF-64or3ARiXoosUOg../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.csv’
#
# Geospatial_data.csv 100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2019-06-15 09:03:10 (29.2 MB/s) - ‘Geospatial_data.csv’ saved [2891/2891]

# %%
Geodata = pd.read_csv("Geospatial_data.csv", delimiter=",")
Geodata[0:7]
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029

# %%
len(list(df['Postcode'].unique()))
# Out:
# 103

# %%
len(list(Geodata['Postal Code'].unique()))
# Out:
# 103

# %%
result = pd.merge(df,
                  Geodata,
                  left_on='Postcode',right_on='Postal Code')
result.head()
# Out:
#   Postcode           Borough                     Neighbourhood Postal Code  \
# 0      M3A        North York                         Parkwoods         M3A
# 1      M4A        North York                  Victoria Village         M4A
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park         M5A
# 3      M6A        North York  Lawrence Heights, Lawrence Manor         M6A
# 4      M7A      Queen's Park                      Queen's Park         M7A
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
result=result.drop(columns=['Postal Code'])

# %% [markdown]
# ## ANSWER TO PART 2

# %%
result
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
result.to_csv('Toronto.csv',index=False)

# %%
df = pd.read_csv("Toronto.csv", delimiter=",")
df.head()
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4      M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
# create map of Toronto using latitude and longitude values
map_to = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, postcode in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Postcode']):
    label = '{}, {}'.format(postcode, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_to)  
    
map_to
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
to_data = df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
to_data.head()
# Out:
#   Postcode           Borough              Neighbourhood   Latitude  Longitude
# 0      M5A  Downtown Toronto  Harbourfront, Regent Park  43.654260 -79.360636
# 1      M5B  Downtown Toronto   Ryerson, Garden District  43.657162 -79.378937
# 2      M5C  Downtown Toronto             St. James Town  43.651494 -79.375418
# 3      M4E      East Toronto                The Beaches  43.676357 -79.293031
# 4      M5E  Downtown Toronto                Berczy Park  43.644771 -79.373306

# %%
# create map of Toronto using latitude and longitude values
map_toto = folium.Map(location=[latitude, longitude], zoom_start=10)
dfbu=df
df = to_data

# add markers to map
for lat, lng, borough, postcode in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Postcode']):
    label = '{}, {}'.format(postcode, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toto)  
    
map_toto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_clustering = to_data.drop(columns=['Postcode','Borough','Neighbourhood'])
toronto_clustering.head()
# Out:
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.657162 -79.378937
# 2  43.651494 -79.375418
# 3  43.676357 -79.293031
# 4  43.644771 -79.373306

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %% [markdown]
# ## Clustering based on the latitude and longtitude of the postcodes

# %%
# set number of clusters
kclusters = 4

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 3, 0, 0, 2, 0, 2, 0], dtype=int32)

# %%
# add clustering labels
to_clusters = to_data
to_clusters.insert(0, 'Cluster Labels', kmeans.labels_)
to_clusters
# Out:
#     Cluster Labels Postcode           Borough  \
# 0                0      M5A  Downtown Toronto
# 1                0      M5B  Downtown Toronto
# 2                0      M5C  Downtown Toronto
# 3                3      M4E      East Toronto
# 4                0      M5E  Downtown Toronto
# 5                0      M5G  Downtown Toronto
# 6                2      M6G  Downtown Toronto
# 7                0      M5H  Downtown Toronto
# 8                2      M6H      West Toronto
# 9                0      M5J  Downtown Toronto
# 10               2      M6J      West Toronto
# 11               3      M4K      East Toronto
# 12               0      M5K  Downtown Toronto
# 13               2      M6K      West Toronto
# 14               3      M4L      East Toronto
# 15               0      M5L  Downtown Toronto
# 16               3      M4M      East Toronto
# 17               1      M4N   Central Toronto
# 18               1      M5N   Central Toronto
# 19               1      M4P   Central Toronto
# 20               1      M5P   Central Toronto
# 21               2      M6P      West Toronto
# 22               1      M4R   Central Toronto
# 23               0      M5R   Central Toronto
# 24               2      M6R      West Toronto
# 25               1      M4S   Central Toronto
# 26               0      M5S  Downtown Toronto
# 27               2      M6S      West Toronto
# 28               1      M4T   Central Toronto
# 29               0      M5T  Downtown Toronto
# 30               1      M4V   Central Toronto
# 31               0      M5V  Downtown Toronto
# 32               0      M4W  Downtown Toronto
# 33               0      M5W  Downtown Toronto
# 34               0      M4X  Downtown Toronto
# 35               0      M5X  Downtown Toronto
# 36               0      M4Y  Downtown Toronto
# 37               3      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                           Harbourfront, Regent Park  43.654260 -79.360636
# 1                            Ryerson, Garden District  43.657162 -79.378937
# 2                                      St. James Town  43.651494 -79.375418
# 3                                         The Beaches  43.676357 -79.293031
# 4                                         Berczy Park  43.644771 -79.373306
# 5                                  Central Bay Street  43.657952 -79.387383
# 6                                            Christie  43.669542 -79.422564
# 7                            Adelaide, King, Richmond  43.650571 -79.384568
# 8                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 9   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 10                           Little Portugal, Trinity  43.647927 -79.419750
# 11                       The Danforth West, Riverdale  43.679557 -79.352188
# 12           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 13       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 14                     The Beaches West, India Bazaar  43.668999 -79.315572
# 15                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 16                                    Studio District  43.659526 -79.340923
# 17                                      Lawrence Park  43.728020 -79.388790
# 18                                           Roselawn  43.711695 -79.416936
# 19                                   Davisville North  43.712751 -79.390197
# 20                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 21                      High Park, The Junction South  43.661608 -79.464763
# 22                                 North Toronto West  43.715383 -79.405678
# 23                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 24                             Parkdale, Roncesvalles  43.648960 -79.456325
# 25                                         Davisville  43.704324 -79.388790
# 26                     Harbord, University of Toronto  43.662696 -79.400049
# 27                                 Runnymede, Swansea  43.651571 -79.484450
# 28                        Moore Park, Summerhill East  43.689574 -79.383160
# 29          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 30  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 31  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 32                                           Rosedale  43.679563 -79.377529
# 33                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 34                        Cabbagetown, St. James Town  43.667967 -79.367675
# 35             First Canadian Place, Underground city  43.648429 -79.382280
# 36                               Church and Wellesley  43.665860 -79.383160
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
import numpy as np # library to handle data in a vectorized manner

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(to_clusters['Latitude'], to_clusters['Longitude'], to_clusters['Postcode'], to_clusters['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
